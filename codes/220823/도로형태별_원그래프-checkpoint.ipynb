# %%
import numpy as np
import pandas as pd
from scipy.stats import *
import matplotlib.pyplot as plt #그래프 패키지 모듈 등록
# %matplotlib inline 
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
data = pd.read_excel('./data/pm_도로형태별_교통사고17~21.xls')
data
# Out:
#                                                 기준년도 2017 2017.1 2017.2  \
# 0                                               기준년도   합계    단일로    단일로
# 1                                               기준년도   합계     합계    교량위
# 2                                               사고건수  117     63      1
# 3                                               사망자수    4      3      0
# 4                                               부상자수  124     65      1
# 5  출처)도로교통공단.&#10;주) 부상자수는 중상자수，경상자수，부상신고자수의 합계.&...  NaN    NaN    NaN
#
#   2017.3 2017.4 2017.5    2017.6 2017.7 2017.8  ...     2021.5 2021.6 2021.7  \
# 0    단일로    교차로    교차로       교차로    교차로     기타  ...        단일로    단일로    교차로
# 1  기타단일로     합계   교차로내  교차로횡단보도내  교차로부근     합계  ...  지하차도(도로)내  기타단일로     합계
# 2     62     32     22         3      7     22  ...         11    791    647
# 3      3      0      0         0      0      1  ...          0      9      7
# 4     64     36     26         3      7     23  ...         12    866    729
# ...

# %%
y_17 = data.iloc[:,2:11].loc[1:]
y_18 = data.iloc[:,12:22].loc[1:]
y_19 = data.iloc[:,23:33].loc[1:]
y_20 = data.iloc[:,34:45].loc[1:]
y_21 = data.iloc[:,46:58].loc[1:]

# %%
# 17년도 데이터
col = y_17.loc[1].to_list()
y_17.columns = col
y_17 = y_17.loc[2:4]
y_17.index = ['사고건수','사망자수','부상자수']
y_17
# 단일로(3), 교차로(4), 기타(2)

# 합계 데이터
sum_17 = y_17.loc[:,['합계']]
sum_17.columns = ['단일로','교차로','기타']
sum_17

# 세부 데이터
del y_17['합계']

# %%
# 18년도 데이터
col = y_18.loc[1].to_list()
y_18.columns = col
y_18 = y_18.loc[2:4]
y_18.index = ['사고건수','사망자수','부상자수']
y_18
# 단일로(4), 교차로(4), 기타(2)

# 합계 데이터
sum_18 = y_18.loc[:,['합계']]
sum_18.columns = ['단일로','교차로','기타']
sum_18

# 세부 데이터
del y_18['합계']

# %%
# 19년도 데이터
col = y_19.loc[1].to_list()
y_19.columns = col
y_19 = y_19.loc[2:4]
y_19.index = ['사고건수','사망자수','부상자수']
y_19
# 단일로(4), 교차로(4), 기타(2)

# 합계 데이터
sum_19 = y_19.loc[:,['합계']]
sum_19.columns = ['단일로','교차로','기타']
sum_19

# 세부 데이터
del y_19['합계']

# %%
# 20년도 데이터
col = y_20.loc[1].to_list()
y_20.columns = col
y_20 = y_20.loc[2:4]
y_20.index = ['사고건수','사망자수','부상자수']
y_20
# 단일로(5), 교차로(4), 기타(2)

# 합계 데이터
sum_20 = y_20.loc[:,['합계']]
sum_20.columns = ['단일로','교차로','기타']
sum_20

# 세부 데이터
del y_20['합계']

# %%
# 21년도 데이터
col = y_21.loc[1].to_list()
y_21.columns = col
y_21 = y_21.loc[2:4]
y_21.index = ['사고건수','사망자수','부상자수']
y_21
# 단일로(6), 교차로(4), 기타(2)

# 합계 데이터
sum_21 = y_21.loc[:,['합계']]
sum_21.columns = ['단일로','교차로','기타']
sum_21

# 세부 데이터
del y_21['합계']

# %%
def customPct(pct) :
    return ('%.1f%%' % pct) if pct > 0 else ''

# %%
labels = sum_17.columns
labels_1 = y_17.columns
size = sum_17.iloc[0].to_list()
size_1 = y_17.iloc[0].to_list()
colors = ['darkred','chocolate','darkgoldenrod','darkslategrey','midnightblue','indigo','midiumvioletred']
colors_1 = ['salmon','lightsalmon','lemonchiffon','paleturquoise','cornflowerblue','mediumpurple','lightpink']

for i in range(len(sum_17.index)):
    size = sum_17.iloc[i].to_list()
    size_1 = y_17.iloc[i].to_list()
    colors=colors
    plt.figure(figsize=(10,10))
    plt.title(sum_17.index[i])

    pie_d = plt.pie(size_1, 
    #         labels=labels_1,
            colors = colors_1, 
            startangle=90, 
            autopct= customPct, 
            shadow=True, 
            textprops={'fontsize': 14},  
            pctdistance = 0.85,
            radius = 1)


    pie = plt.pie(size, 
            labels='<'+labels+'>', 
    #       explode=[0.05]*3, 
            colors = colors, 
            startangle=90, 
            autopct= customPct, 
            shadow=True, 
            textprops={'fontsize': 12},  
            pctdistance = 0.85,
            radius = 0.75,
            labeldistance=0.4)
    
    plt.legend(labels=labels_1,loc='best')
    centre_circle = plt.Circle((0,0),0.50,fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)

# %%
labels = sum_18.columns
labels_1 = y_18.columns
size = sum_18.iloc[0].to_list()
size_1 = y_18.iloc[0].to_list()
colors = ['darkred','chocolate','darkgoldenrod','darkslategrey','midnightblue','indigo','midiumvioletred']
colors_1 = ['salmon','lightsalmon','lemonchiffon','paleturquoise','cornflowerblue','mediumpurple','lightpink']

for i in range(len(sum_18.index)):
    size = sum_18.iloc[i].to_list()
    size_1 = y_18.iloc[i].to_list()
    colors=colors
    plt.figure(figsize=(10,10))
    plt.title(sum_18.index[i])

    pie_d = plt.pie(size_1, 
    #         labels=labels_1,
            colors = colors_1, 
            startangle=90, 
            autopct= customPct, 
            shadow=True, 
            textprops={'fontsize': 14},  
            pctdistance = 0.85,
            radius = 1)


    pie = plt.pie(size, 
            labels='<'+labels+'>', 
    #       explode=[0.05]*3, 
            colors = colors, 
            startangle=90, 
            autopct= customPct, 
            shadow=True, 
            textprops={'fontsize': 12},  
            pctdistance = 0.85,
            radius = 0.75,
            labeldistance=0.4)
    
    plt.legend(labels=labels_1,loc='best')
    centre_circle = plt.Circle((0,0),0.50,fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)

# %%
labels = sum_19.columns
labels_1 = y_19.columns
size = sum_19.iloc[0].to_list()
size_1 = y_19.iloc[0].to_list()
colors = ['darkred','chocolate','darkgoldenrod','darkslategrey','midnightblue','indigo','midiumvioletred']
colors_1 = ['salmon','lightsalmon','lemonchiffon','paleturquoise','cornflowerblue','mediumpurple','lightpink']

for i in range(len(sum_19.index)):
    size = sum_19.iloc[i].to_list()
    size_1 = y_19.iloc[i].to_list()
    colors=colors
    plt.figure(figsize=(10,10))
    plt.title(sum_19.index[i])

    pie_d = plt.pie(size_1, 
    #         labels=labels_1,
            colors = colors_1, 
            startangle=90, 
            autopct= customPct, 
            shadow=True, 
            textprops={'fontsize': 14},  
            pctdistance = 0.85,
            radius = 1)


    pie = plt.pie(size, 
            labels='<'+labels+'>', 
    #       explode=[0.05]*3, 
            colors = colors, 
            startangle=90, 
            autopct= customPct, 
            shadow=True, 
            textprops={'fontsize': 12},  
            pctdistance = 0.85,
            radius = 0.75,
            labeldistance=0.4)
    
    plt.legend(labels=labels_1,loc='best')
    centre_circle = plt.Circle((0,0),0.50,fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)

# %%
labels = sum_20.columns
labels_1 = y_20.columns
size = sum_20.iloc[0].to_list()
size_1 = y_20.iloc[0].to_list()
colors = ['darkred','chocolate','darkgoldenrod','darkslategrey','midnightblue','indigo','midiumvioletred']
colors_1 = ['salmon','lightsalmon','lemonchiffon','paleturquoise','cornflowerblue','mediumpurple','lightpink']

for i in range(len(sum_20.index)):
    size = sum_20.iloc[i].to_list()
    size_1 = y_20.iloc[i].to_list()
    colors=colors
    plt.figure(figsize=(10,10))
    plt.title(sum_20.index[i])

    pie_d = plt.pie(size_1, 
    #         labels=labels_1,
            colors = colors_1, 
            startangle=90, 
            autopct= customPct, 
            shadow=True, 
            textprops={'fontsize': 14},  
            pctdistance = 1.1,
            radius = 1)


    pie = plt.pie(size, 
            labels='<'+labels+'>', 
    #       explode=[0.05]*3, 
            colors = colors, 
            startangle=90, 
            autopct= customPct, 
            shadow=True, 
            textprops={'fontsize': 12},  
            pctdistance = 0.85,
            radius = 0.75,
            labeldistance=0.4)
    
    plt.legend(labels=labels_1,loc='best')
    centre_circle = plt.Circle((0,0),0.50,fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)

# %%
labels = sum_21.columns
labels_1 = y_21.columns
size = sum_21.iloc[0].to_list()
size_1 = y_21.iloc[0].to_list()
colors = ['darkred','chocolate','darkgoldenrod','darkslategrey','midnightblue','indigo','midiumvioletred']
colors_1 = ['salmon','lightsalmon','lemonchiffon','paleturquoise','cornflowerblue','mediumpurple','lightpink']

for i in range(len(sum_21.index)):
    size = sum_21.iloc[i].to_list()
    size_1 = y_21.iloc[i].to_list()
    colors=colors
    plt.figure(figsize=(10,10))
    plt.title(sum_21.index[i])

    pie_d = plt.pie(size_1, 
    #         labels=labels_1,
            colors = colors_1, 
            startangle=90, 
            autopct= customPct, 
            shadow=True, 
            textprops={'fontsize': 14},  
            pctdistance = 1.1,
            radius = 1)


    pie = plt.pie(size, 
            labels='<'+labels+'>', 
    #       explode=[0.05]*3, 
            colors = colors, 
            startangle=90, 
            autopct= customPct, 
            shadow=True, 
            textprops={'fontsize': 12},  
            pctdistance = 0.85,
            radius = 0.75,
            labeldistance=0.4)
    
    plt.legend(labels=labels_1,loc='best')
    centre_circle = plt.Circle((0,0),0.50,fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)
