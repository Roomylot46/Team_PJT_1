# %%
# 필요 모듈 import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
# 데이터 읽어오기
df = pd.read_excel('자료/가해자연령대별_17-21.xls')
df
# Out:
#          연령층  2017 2017.1 2017.2  2018 2018.1 2018.2  2019 2019.1 2019.2  \
# 0  가해운전자 연령층  사고건수   사망자수   부상자수  사고건수   사망자수   부상자수  사고건수   사망자수   부상자수
# 1      20세이하    16      0     16    25      0     29    59      0     69
# 2        20대    28      1     32    74      0     79   156      0    168
# 3        30대    21      1     22    40      0     43    97      3     99
# 4        40대    21      0     23    37      2     38    52      1     54
# 5        50대    15      1     14    20      1     20    46      0     47
# 6        60대     0      0      0     8      0      8     8      1      7
# 7      65세이상    14      1     15    20      1     20    25      3     25
# 8         불명     2      0      2     1      0      1     4      0      4
# 9         합계   117      4    124   225      4    238   447      8    473
#
#    2020 2020.1 2020.2  2021 2021.1 2021.2
# 0  사고건수   사망자수   부상자수  사고건수   사망자수   부상자수
# 1   209      1    244   628      3    710
# ...

# %%
df.rename(columns=df.iloc[0],inplace=True)
df
# Out:
#    가해운전자 연령층  사고건수  사망자수  부상자수  사고건수  사망자수  부상자수  사고건수  사망자수  부상자수  사고건수  \
# 0  가해운전자 연령층  사고건수  사망자수  부상자수  사고건수  사망자수  부상자수  사고건수  사망자수  부상자수  사고건수
# 1      20세이하    16     0    16    25     0    29    59     0    69   209
# 2        20대    28     1    32    74     0    79   156     0   168   314
# 3        30대    21     1    22    40     0    43    97     3    99   163
# 4        40대    21     0    23    37     2    38    52     1    54    99
# 5        50대    15     1    14    20     1    20    46     0    47    59
# 6        60대     0     0     0     8     0     8     8     1     7    17
# 7      65세이상    14     1    15    20     1    20    25     3    25    30
# 8         불명     2     0     2     1     0     1     4     0     4     6
# 9         합계   117     4   124   225     4   238   447     8   473   897
#
#    사망자수  부상자수  사고건수  사망자수  부상자수
# 0  사망자수  부상자수  사고건수  사망자수  부상자수
# 1     1   244   628     3   710
# 2     2   338   555     2   604
# 3     0   176   218     4   239
# ...

# %%
df1=df.drop([0,9],axis=0)
df1
# Out:
#   가해운전자 연령층 사고건수 사망자수 부상자수 사고건수 사망자수 부상자수 사고건수 사망자수 부상자수 사고건수 사망자수 부상자수 사고건수  \
# 1     20세이하   16    0   16   25    0   29   59    0   69  209    1  244  628
# 2       20대   28    1   32   74    0   79  156    0  168  314    2  338  555
# 3       30대   21    1   22   40    0   43   97    3   99  163    0  176  218
# 4       40대   21    0   23   37    2   38   52    1   54   99    1  109  138
# 5       50대   15    1   14   20    1   20   46    0   47   59    4   59   89
# 6       60대    0    0    0    8    0    8    8    1    7   17    0   19   19
# 7     65세이상   14    1   15   20    1   20   25    3   25   30    2   34   62
# 8        불명    2    0    2    1    0    1    4    0    4    6    0    6   26
#
#   사망자수 부상자수
# 1    3  710
# 2    2  604
# 3    4  239
# 4    3  146
# 5    3   94
# 6    3   16
# 7    1   66
# 8    0   26

# %%
df1=df1.transpose()
df1
# Out:
#                1    2    3    4    5    6      7   8
# 가해운전자 연령층  20세이하  20대  30대  40대  50대  60대  65세이상  불명
# 사고건수          16   28   21   21   15    0     14   2
# 사망자수           0    1    1    0    1    0      1   0
# 부상자수          16   32   22   23   14    0     15   2
# 사고건수          25   74   40   37   20    8     20   1
# 사망자수           0    0    0    2    1    0      1   0
# 부상자수          29   79   43   38   20    8     20   1
# 사고건수          59  156   97   52   46    8     25   4
# 사망자수           0    0    3    1    0    1      3   0
# 부상자수          69  168   99   54   47    7     25   4
# 사고건수         209  314  163   99   59   17     30   6
# 사망자수           1    2    0    1    4    0      2   0
# 부상자수         244  338  176  109   59   19     34   6
# 사고건수         628  555  218  138   89   19     62  26
# 사망자수           3    2    4    3    3    3      1   0
# 부상자수         710  604  239  146   94   16     66  26

# %%
df1.columns=['10대','20대','30대','40대','50대','60대','65세이상','불명']
df1
# Out:
#              10대  20대  30대  40대  50대  60대  65세이상  불명
# 가해운전자 연령층  20세이하  20대  30대  40대  50대  60대  65세이상  불명
# 사고건수          16   28   21   21   15    0     14   2
# 사망자수           0    1    1    0    1    0      1   0
# 부상자수          16   32   22   23   14    0     15   2
# 사고건수          25   74   40   37   20    8     20   1
# 사망자수           0    0    0    2    1    0      1   0
# 부상자수          29   79   43   38   20    8     20   1
# 사고건수          59  156   97   52   46    8     25   4
# 사망자수           0    0    3    1    0    1      3   0
# 부상자수          69  168   99   54   47    7     25   4
# 사고건수         209  314  163   99   59   17     30   6
# 사망자수           1    2    0    1    4    0      2   0
# 부상자수         244  338  176  109   59   19     34   6
# 사고건수         628  555  218  138   89   19     62  26
# 사망자수           3    2    4    3    3    3      1   0
# 부상자수         710  604  239  146   94   16     66  26

# %%
df2 = df1.loc[['사고건수']]
df2
# Out:
#       10대  20대  30대  40대 50대 60대 65세이상  불명
# 사고건수   16   28   21   21  15   0    14   2
# 사고건수   25   74   40   37  20   8    20   1
# 사고건수   59  156   97   52  46   8    25   4
# 사고건수  209  314  163   99  59  17    30   6
# 사고건수  628  555  218  138  89  19    62  26

# %%
df2.index=['2017사고건수','2018사고건수','2019사고건수','2020사고건수','2021사고건수']
df2
# Out:
#           10대  20대  30대  40대 50대 60대 65세이상  불명
# 2017사고건수   16   28   21   21  15   0    14   2
# 2018사고건수   25   74   40   37  20   8    20   1
# 2019사고건수   59  156   97   52  46   8    25   4
# 2020사고건수  209  314  163   99  59  17    30   6
# 2021사고건수  628  555  218  138  89  19    62  26

# %%
df2_7 = df2.loc['2017사고건수']
df2_7
# Out:
# 10대      16
# 20대      28
# 30대      21
# 40대      21
# 50대      15
# 60대       0
# 65세이상    14
# 불명        2
# Name: 2017사고건수, dtype: object

# %%
df2_7.plot(figsize=(5,5),kind = 'barh',grid= True,rot = 0,edgecolor='black',
           color = ('blue','red','blue','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2017년 연령별 사고건수', fontsize=20)
plt.xlabel('사고건수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.savefig(f'./2017년 연령별사고건수.jpg')

# %%
df2_8 = df2.loc['2018사고건수']
df2_8
# Out:
# 10대      25
# 20대      74
# 30대      40
# 40대      37
# 50대      20
# 60대       8
# 65세이상    20
# 불명        1
# Name: 2018사고건수, dtype: object

# %%
df2_8.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = ('blue','red','blue','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2018년 연령별 사고건수', fontsize=20)
plt.xlabel('사고건수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.savefig(f'./2018년 연령별사고건수.jpg')

# %%
df2_9 = df2.loc['2019사고건수']
df2_9
# Out:
# 10대       59
# 20대      156
# 30대       97
# 40대       52
# 50대       46
# 60대        8
# 65세이상     25
# 불명         4
# Name: 2019사고건수, dtype: object

# %%
df2_9.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = ('blue','red','blue','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2019년 연령별 사고건수', fontsize=20)
plt.xlabel('사고건수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.savefig(f'./2019년 연령별사고건수.jpg')

# %%
df2_0 = df2.loc['2020사고건수']
df2_0
# Out:
# 10대      209
# 20대      314
# 30대      163
# 40대       99
# 50대       59
# 60대       17
# 65세이상     30
# 불명         6
# Name: 2020사고건수, dtype: object

# %%
df2_0.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
             color = ('blue','red','blue','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2020년 연령별 사고건수', fontsize=20)
plt.xlabel('사고건수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.savefig(f'./2020년 연령별사고건수.jpg')

# %%
df2_1 = df2.loc['2021사고건수']
df2_1
# Out:
# 10대      628
# 20대      555
# 30대      218
# 40대      138
# 50대       89
# 60대       19
# 65세이상     62
# 불명        26
# Name: 2021사고건수, dtype: object

# %%
df2_1.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = ('red','blue','blue','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2021년 연령별 사고건수', fontsize=20)
plt.xlabel('사고건수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.savefig(f'./2021년 연령별사고건수.jpg')

# %%
df1
# Out:
#              10대  20대  30대  40대  50대  60대  65세이상  불명
# 가해운전자 연령층  20세이하  20대  30대  40대  50대  60대  65세이상  불명
# 사고건수          16   28   21   21   15    0     14   2
# 사망자수           0    1    1    0    1    0      1   0
# 부상자수          16   32   22   23   14    0     15   2
# 사고건수          25   74   40   37   20    8     20   1
# 사망자수           0    0    0    2    1    0      1   0
# 부상자수          29   79   43   38   20    8     20   1
# 사고건수          59  156   97   52   46    8     25   4
# 사망자수           0    0    3    1    0    1      3   0
# 부상자수          69  168   99   54   47    7     25   4
# 사고건수         209  314  163   99   59   17     30   6
# 사망자수           1    2    0    1    4    0      2   0
# 부상자수         244  338  176  109   59   19     34   6
# 사고건수         628  555  218  138   89   19     62  26
# 사망자수           3    2    4    3    3    3      1   0
# 부상자수         710  604  239  146   94   16     66  26

# %%
df3 = df1.loc[['부상자수']]
df3
# Out:
#       10대  20대  30대  40대 50대 60대 65세이상  불명
# 부상자수   16   32   22   23  14   0    15   2
# 부상자수   29   79   43   38  20   8    20   1
# 부상자수   69  168   99   54  47   7    25   4
# 부상자수  244  338  176  109  59  19    34   6
# 부상자수  710  604  239  146  94  16    66  26

# %%
df3.index=['2017부상자수','2018부상자수','2019부상자수','2020부상자수','2021부상자수',]
df3
# Out:
#           10대  20대  30대  40대 50대 60대 65세이상  불명
# 2017부상자수   16   32   22   23  14   0    15   2
# 2018부상자수   29   79   43   38  20   8    20   1
# 2019부상자수   69  168   99   54  47   7    25   4
# 2020부상자수  244  338  176  109  59  19    34   6
# 2021부상자수  710  604  239  146  94  16    66  26

# %%
df3_7 = df3.loc['2017부상자수']
df3_7
# Out:
# 10대      16
# 20대      32
# 30대      22
# 40대      23
# 50대      14
# 60대       0
# 65세이상    15
# 불명        2
# Name: 2017부상자수, dtype: object

# %%
df_7=df3_7.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
               color = ('blue','red','blue','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2017년 연령별 부상자수', fontsize=20)
plt.xlabel('부상자수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.savefig(f'./2017년 연령별부상자수.jpg')

# %%
df3_8 = df3.loc['2018부상자수']
df3_8
# Out:
# 10대      29
# 20대      79
# 30대      43
# 40대      38
# 50대      20
# 60대       8
# 65세이상    20
# 불명        1
# Name: 2018부상자수, dtype: object

# %%
df3_8.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = ('blue','red','blue','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2018년 연령별 부상자수', fontsize=20)
plt.xlabel('부상자수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.savefig(f'./2018년 연령별부상자수.jpg')

# %%
df3_9 = df3.loc['2019부상자수']
df3_9
# Out:
# 10대       69
# 20대      168
# 30대       99
# 40대       54
# 50대       47
# 60대        7
# 65세이상     25
# 불명         4
# Name: 2019부상자수, dtype: object

# %%
df3_9.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = ('blue','red','blue','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2019년 연령별 부상자수', fontsize=20)
plt.xlabel('부상자수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.savefig(f'./2019년 연령별부상자수.jpg')

# %%
df3_0 = df3.loc['2020부상자수']
df3_0
# Out:
# 10대      244
# 20대      338
# 30대      176
# 40대      109
# 50대       59
# 60대       19
# 65세이상     34
# 불명         6
# Name: 2020부상자수, dtype: object

# %%
df3_0.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = ('blue','red','blue','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2020년 연령별 부상자수', fontsize=20)
plt.xlabel('부상자수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.savefig(f'./2020년 연령별부상자수.jpg')

# %%
df3_1 = df3.loc['2021부상자수']
df3_1
# Out:
# 10대      710
# 20대      604
# 30대      239
# 40대      146
# 50대       94
# 60대       16
# 65세이상     66
# 불명        26
# Name: 2021부상자수, dtype: object

# %%
df3_1.plot(figsize=(5,5),kind = 'barh', grid= True,title = '2021년 연령별 부상자수',rot = 0,edgecolor='black',
          color = ('red','blue','blue','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2021년 연령별 부상자수', fontsize=20)
plt.xlabel('부상자수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
# Out:
# Text(0, 0.5, '연령별')

# %%
df1
# Out:
#              10대  20대  30대  40대  50대  60대  65세이상  불명
# 가해운전자 연령층  20세이하  20대  30대  40대  50대  60대  65세이상  불명
# 사고건수          16   28   21   21   15    0     14   2
# 사망자수           0    1    1    0    1    0      1   0
# 부상자수          16   32   22   23   14    0     15   2
# 사고건수          25   74   40   37   20    8     20   1
# 사망자수           0    0    0    2    1    0      1   0
# 부상자수          29   79   43   38   20    8     20   1
# 사고건수          59  156   97   52   46    8     25   4
# 사망자수           0    0    3    1    0    1      3   0
# 부상자수          69  168   99   54   47    7     25   4
# 사고건수         209  314  163   99   59   17     30   6
# 사망자수           1    2    0    1    4    0      2   0
# 부상자수         244  338  176  109   59   19     34   6
# 사고건수         628  555  218  138   89   19     62  26
# 사망자수           3    2    4    3    3    3      1   0
# 부상자수         710  604  239  146   94   16     66  26

# %%
df4 = df1.loc[['사망자수']]
df4
# Out:
#      10대 20대 30대 40대 50대 60대 65세이상 불명
# 사망자수   0   1   1   0   1   0     1  0
# 사망자수   0   0   0   2   1   0     1  0
# 사망자수   0   0   3   1   0   1     3  0
# 사망자수   1   2   0   1   4   0     2  0
# 사망자수   3   2   4   3   3   3     1  0

# %%
df4.index=['2017사망자수','2018사망자수','2019사망자수','2020사망자수','2021사망자수']
df4
# Out:
#          10대 20대 30대 40대 50대 60대 65세이상 불명
# 2017사망자수   0   1   1   0   1   0     1  0
# 2018사망자수   0   0   0   2   1   0     1  0
# 2019사망자수   0   0   3   1   0   1     3  0
# 2020사망자수   1   2   0   1   4   0     2  0
# 2021사망자수   3   2   4   3   3   3     1  0

# %%
df4_7= df4.loc['2017사망자수']
df4_7
# Out:
# 10대      0
# 20대      1
# 30대      1
# 40대      0
# 50대      1
# 60대      0
# 65세이상    1
# 불명       0
# Name: 2017사망자수, dtype: object

# %%
df4_7.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = 'red',fontsize=15)
plt.title('2017년 연령별 사망자수', fontsize=20)
plt.xlabel('사망자수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.xlim(0,5)
plt.savefig(f'./2017년 연령별사망자수.jpg')

# %%
df4_8= df4.loc['2018사망자수']
df4_8
# Out:
# 10대      0
# 20대      0
# 30대      0
# 40대      2
# 50대      1
# 60대      0
# 65세이상    1
# 불명       0
# Name: 2018사망자수, dtype: object

# %%
df4_8.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = ('blue','blue','blue','red','blue','blue','blue','blue'),fontsize=15)
plt.title('2018년 연령별 사망자수', fontsize=20)
plt.xlabel('사망자수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.xlim(0,5)
plt.savefig(f'./2018년 연령별사망자수.jpg')

# %%
df4_9 = df4.loc['2019사망자수']
df4_9
# Out:
# 10대      0
# 20대      0
# 30대      3
# 40대      1
# 50대      0
# 60대      1
# 65세이상    3
# 불명       0
# Name: 2019사망자수, dtype: object

# %%
df4_9.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = ('blue','blue','red','blue','blue','blue','red','blue'),fontsize=15)
plt.title('2019년 연령별 사망자수', fontsize=20)
plt.xlabel('사망자수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.xlim(0,5)
plt.savefig(f'./2019년 연령별사망자수.jpg')

# %%
df4_0 = df4.loc['2020사망자수']
df4_0
# Out:
# 10대      1
# 20대      2
# 30대      0
# 40대      1
# 50대      4
# 60대      0
# 65세이상    2
# 불명       0
# Name: 2020사망자수, dtype: object

# %%
df4_0.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = ('blue','blue','blue','blue','red','blue','blue','blue'),fontsize=15)
plt.title('2020년 연령별 사망자수', fontsize=20)
plt.xlabel('사망자수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.xlim(0,5)
plt.savefig(f'./2020년 연령별사망자수.jpg')

# %%
df4_1 = df4.loc['2021사망자수']
df4_1
# Out:
# 10대      3
# 20대      2
# 30대      4
# 40대      3
# 50대      3
# 60대      3
# 65세이상    1
# 불명       0
# Name: 2021사망자수, dtype: object

# %%
df4_1.plot(figsize=(5,5),kind = 'barh', grid= True,rot = 0,edgecolor='black',
          color = ('blue','blue','red','blue','blue','blue','blue','blue'),fontsize=15)
plt.title('2021년 연령별 사망자수', fontsize=20)
plt.xlabel('사망자수',fontsize=15)
plt.ylabel('연령별',fontsize=15)
plt.xlim(0,5)
plt.savefig(f'./2020년 연령별사망자수.jpg')

# %%
df = pd.read_excel('자료/가해자연령대별_17-21.xls')
df
# Out:
#          연령층  2017 2017.1 2017.2  2018 2018.1 2018.2  2019 2019.1 2019.2  \
# 0  가해운전자 연령층  사고건수   사망자수   부상자수  사고건수   사망자수   부상자수  사고건수   사망자수   부상자수
# 1      20세이하    16      0     16    25      0     29    59      0     69
# 2        20대    28      1     32    74      0     79   156      0    168
# 3        30대    21      1     22    40      0     43    97      3     99
# 4        40대    21      0     23    37      2     38    52      1     54
# 5        50대    15      1     14    20      1     20    46      0     47
# 6        60대     0      0      0     8      0      8     8      1      7
# 7      65세이상    14      1     15    20      1     20    25      3     25
# 8         불명     2      0      2     1      0      1     4      0      4
# 9         합계   117      4    124   225      4    238   447      8    473
#
#    2020 2020.1 2020.2  2021 2021.1 2021.2
# 0  사고건수   사망자수   부상자수  사고건수   사망자수   부상자수
# 1   209      1    244   628      3    710
# ...

# %%
df.rename(columns=df.iloc[0],inplace=True)
df
# Out:
#    가해운전자 연령층  사고건수  사망자수  부상자수  사고건수  사망자수  부상자수  사고건수  사망자수  부상자수  사고건수  \
# 0  가해운전자 연령층  사고건수  사망자수  부상자수  사고건수  사망자수  부상자수  사고건수  사망자수  부상자수  사고건수
# 1      20세이하    16     0    16    25     0    29    59     0    69   209
# 2        20대    28     1    32    74     0    79   156     0   168   314
# 3        30대    21     1    22    40     0    43    97     3    99   163
# 4        40대    21     0    23    37     2    38    52     1    54    99
# 5        50대    15     1    14    20     1    20    46     0    47    59
# 6        60대     0     0     0     8     0     8     8     1     7    17
# 7      65세이상    14     1    15    20     1    20    25     3    25    30
# 8         불명     2     0     2     1     0     1     4     0     4     6
# 9         합계   117     4   124   225     4   238   447     8   473   897
#
#    사망자수  부상자수  사고건수  사망자수  부상자수
# 0  사망자수  부상자수  사고건수  사망자수  부상자수
# 1     1   244   628     3   710
# 2     2   338   555     2   604
# 3     0   176   218     4   239
# ...

# %%
df1=df.drop([0,9],axis=0)
df1
# Out:
#   가해운전자 연령층 사고건수 사망자수 부상자수 사고건수 사망자수 부상자수 사고건수 사망자수 부상자수 사고건수 사망자수 부상자수 사고건수  \
# 1     20세이하   16    0   16   25    0   29   59    0   69  209    1  244  628
# 2       20대   28    1   32   74    0   79  156    0  168  314    2  338  555
# 3       30대   21    1   22   40    0   43   97    3   99  163    0  176  218
# 4       40대   21    0   23   37    2   38   52    1   54   99    1  109  138
# 5       50대   15    1   14   20    1   20   46    0   47   59    4   59   89
# 6       60대    0    0    0    8    0    8    8    1    7   17    0   19   19
# 7     65세이상   14    1   15   20    1   20   25    3   25   30    2   34   62
# 8        불명    2    0    2    1    0    1    4    0    4    6    0    6   26
#
#   사망자수 부상자수
# 1    3  710
# 2    2  604
# 3    4  239
# 4    3  146
# 5    3   94
# 6    3   16
# 7    1   66
# 8    0   26

# %%
df1=df1.transpose()
df1
# Out:
#                1    2    3    4    5    6      7   8
# 가해운전자 연령층  20세이하  20대  30대  40대  50대  60대  65세이상  불명
# 사고건수          16   28   21   21   15    0     14   2
# 사망자수           0    1    1    0    1    0      1   0
# 부상자수          16   32   22   23   14    0     15   2
# 사고건수          25   74   40   37   20    8     20   1
# 사망자수           0    0    0    2    1    0      1   0
# 부상자수          29   79   43   38   20    8     20   1
# 사고건수          59  156   97   52   46    8     25   4
# 사망자수           0    0    3    1    0    1      3   0
# 부상자수          69  168   99   54   47    7     25   4
# 사고건수         209  314  163   99   59   17     30   6
# 사망자수           1    2    0    1    4    0      2   0
# 부상자수         244  338  176  109   59   19     34   6
# 사고건수         628  555  218  138   89   19     62  26
# 사망자수           3    2    4    3    3    3      1   0
# 부상자수         710  604  239  146   94   16     66  26

# %%
df1.columns=['10대','20대','30대','40대','50대','60대','65세이상','불명']
df1
# Out:
#              10대  20대  30대  40대  50대  60대  65세이상  불명
# 가해운전자 연령층  20세이하  20대  30대  40대  50대  60대  65세이상  불명
# 사고건수          16   28   21   21   15    0     14   2
# 사망자수           0    1    1    0    1    0      1   0
# 부상자수          16   32   22   23   14    0     15   2
# 사고건수          25   74   40   37   20    8     20   1
# 사망자수           0    0    0    2    1    0      1   0
# 부상자수          29   79   43   38   20    8     20   1
# 사고건수          59  156   97   52   46    8     25   4
# 사망자수           0    0    3    1    0    1      3   0
# 부상자수          69  168   99   54   47    7     25   4
# 사고건수         209  314  163   99   59   17     30   6
# 사망자수           1    2    0    1    4    0      2   0
# 부상자수         244  338  176  109   59   19     34   6
# 사고건수         628  555  218  138   89   19     62  26
# 사망자수           3    2    4    3    3    3      1   0
# 부상자수         710  604  239  146   94   16     66  26

# %%
df1.drop(['가해운전자 연령층'],axis=0,inplace=True)
df1
# Out:
#       10대  20대  30대  40대 50대 60대 65세이상  불명
# 사고건수   16   28   21   21  15   0    14   2
# 사망자수    0    1    1    0   1   0     1   0
# 부상자수   16   32   22   23  14   0    15   2
# 사고건수   25   74   40   37  20   8    20   1
# 사망자수    0    0    0    2   1   0     1   0
# 부상자수   29   79   43   38  20   8    20   1
# 사고건수   59  156   97   52  46   8    25   4
# 사망자수    0    0    3    1   0   1     3   0
# 부상자수   69  168   99   54  47   7    25   4
# 사고건수  209  314  163   99  59  17    30   6
# 사망자수    1    2    0    1   4   0     2   0
# 부상자수  244  338  176  109  59  19    34   6
# 사고건수  628  555  218  138  89  19    62  26
# 사망자수    3    2    4    3   3   3     1   0
# 부상자수  710  604  239  146  94  16    66  26

# %%
df1.index = ['17 사고건수','17 사망자수', '17 부상자수', 
          '18 사고건수','18 사망자수', '18 부상자수', 
          '19 사고건수','19 사망자수', '19 부상자수', 
          '20 사고건수','20 사망자수', '20 부상자수',
          '21 사고건수','21 사망자수', '21 부상자수']
df1
# Out:
#          10대  20대  30대  40대 50대 60대 65세이상  불명
# 17 사고건수   16   28   21   21  15   0    14   2
# 17 사망자수    0    1    1    0   1   0     1   0
# 17 부상자수   16   32   22   23  14   0    15   2
# 18 사고건수   25   74   40   37  20   8    20   1
# 18 사망자수    0    0    0    2   1   0     1   0
# 18 부상자수   29   79   43   38  20   8    20   1
# 19 사고건수   59  156   97   52  46   8    25   4
# 19 사망자수    0    0    3    1   0   1     3   0
# 19 부상자수   69  168   99   54  47   7    25   4
# 20 사고건수  209  314  163   99  59  17    30   6
# 20 사망자수    1    2    0    1   4   0     2   0
# 20 부상자수  244  338  176  109  59  19    34   6
# 21 사고건수  628  555  218  138  89  19    62  26
# 21 사망자수    3    2    4    3   3   3     1   0
# 21 부상자수  710  604  239  146  94  16    66  26

# %%
df1_2017 = df1.iloc[:3,:]
df1_2017
# Out:
#         10대 20대 30대 40대 50대 60대 65세이상 불명
# 17 사고건수  16  28  21  21  15   0    14  2
# 17 사망자수   0   1   1   0   1   0     1  0
# 17 부상자수  16  32  22  23  14   0    15  2

# %%
df1_2018 = df1.iloc[3:6,:]
df1_2018
# Out:
#         10대 20대 30대 40대 50대 60대 65세이상 불명
# 18 사고건수  25  74  40  37  20   8    20  1
# 18 사망자수   0   0   0   2   1   0     1  0
# 18 부상자수  29  79  43  38  20   8    20  1

# %%
df1_2019 = df1.iloc[6:9,:]
df1_2019
# Out:
#         10대  20대 30대 40대 50대 60대 65세이상 불명
# 19 사고건수  59  156  97  52  46   8    25  4
# 19 사망자수   0    0   3   1   0   1     3  0
# 19 부상자수  69  168  99  54  47   7    25  4

# %%
df1_2020 = df1.iloc[9:12,:]
df1_2020
# Out:
#          10대  20대  30대  40대 50대 60대 65세이상 불명
# 20 사고건수  209  314  163   99  59  17    30  6
# 20 사망자수    1    2    0    1   4   0     2  0
# 20 부상자수  244  338  176  109  59  19    34  6

# %%
df1_2021 = df1.iloc[12:15,:]
df1_2021
# Out:
#          10대  20대  30대  40대 50대 60대 65세이상  불명
# 21 사고건수  628  555  218  138  89  19    62  26
# 21 사망자수    3    2    4    3   3   3     1   0
# 21 부상자수  710  604  239  146  94  16    66  26

# %%
df2
# Out:
#           10대  20대  30대  40대 50대 60대 65세이상  불명
# 2017사고건수   16   28   21   21  15   0    14   2
# 2018사고건수   25   74   40   37  20   8    20   1
# 2019사고건수   59  156   97   52  46   8    25   4
# 2020사고건수  209  314  163   99  59  17    30   6
# 2021사고건수  628  555  218  138  89  19    62  26

# %%
accidents = df2['10대'].astype(int)
list_acc1 = []
for i in range(len(accidents)-1):
    rate = accidents[i+1] / accidents[i]
    list_acc1.append(rate)

accidents = df2['20대'].astype(int)
list_acc2 = []
for i in range(len(accidents)-1):
    rate = accidents[i+1] / accidents[i]
    list_acc2.append(rate)

accidents = df2['30대'].astype(int)
list_acc3 = []
for i in range(len(accidents)-1):
    rate = accidents[i+1] / accidents[i]
    list_acc3.append(rate)

accidents = df2['40대'].astype(int)
list_acc4 = []
for i in range(len(accidents)-1):
    rate = accidents[i+1] / accidents[i]
    list_acc4.append(rate)

accidents = df2['50대'].astype(int)
list_acc5 = []
for i in range(len(accidents)-1):
    rate = accidents[i+1] / accidents[i]
    list_acc5.append(rate)

accidents = df2['60대'].astype(int)
list_acc6 = []
for i in range(len(accidents)-1):
    rate = accidents[i+1] / accidents[i]
    list_acc6.append(rate)
    
accidents = df2['65세이상'].astype(int)
list_acc7 = []
for i in range(len(accidents)-1):
    rate = accidents[i+1] / accidents[i]
    list_acc7.append(rate)
    
accidents = df2['불명'].astype(int)
list_acc8 = []
for i in range(len(accidents)-1):
    rate = accidents[i+1] / accidents[i]
    list_acc8.append(rate) 
    
    
key = ['10대','20대','30대','40대','50대','60대','65세이상','불명']
list_acc = [list_acc1, list_acc2, list_acc3,list_acc4,list_acc5,list_acc6,list_acc7,list_acc8]
dict_data = dict(zip(key,list_acc))
df_acc = pd.DataFrame(dict_data)
df_acc.index = ['17-18 증가율', '18-19 증가율', '19-20 증가율', '20-21 증가율']
df_acc
# Out:
# C:\Users\taehyun\AppData\Local\Temp\ipykernel_9804\3360269464.py:34: RuntimeWarning: divide by zero encountered in long_scalars
#   rate = accidents[i+1] / accidents[i]
#                 10대       20대       30대       40대       50대       60대  \
# 17-18 증가율  1.562500  2.642857  1.904762  1.761905  1.333333       inf
# 18-19 증가율  2.360000  2.108108  2.425000  1.405405  2.300000  1.000000
# 19-20 증가율  3.542373  2.012821  1.680412  1.903846  1.282609  2.125000
# 20-21 증가율  3.004785  1.767516  1.337423  1.393939  1.508475  1.117647
#
#               65세이상        불명
# 17-18 증가율  1.428571  0.500000
# 18-19 증가율  1.250000  4.000000
# 19-20 증가율  1.200000  1.500000
# 20-21 증가율  2.066667  4.333333

# %%
df3
# Out:
#           10대  20대  30대  40대 50대 60대 65세이상  불명
# 2017부상자수   16   32   22   23  14   0    15   2
# 2018부상자수   29   79   43   38  20   8    20   1
# 2019부상자수   69  168   99   54  47   7    25   4
# 2020부상자수  244  338  176  109  59  19    34   6
# 2021부상자수  710  604  239  146  94  16    66  26

# %%
injs = df3['10대'].astype(int)
list_inj1 = []
for i in range(len(injs)-1):
    rate = injs[i+1] / injs[i]
    list_inj1.append(rate)

injs = df3['20대'].astype(int)
list_inj2 = []
for i in range(len(injs)-1):
    rate = injs[i+1] / injs[i]
    list_inj2.append(rate)

injs = df3['30대'].astype(int)
list_inj3 = []
for i in range(len(injs)-1):
    rate = injs[i+1] / injs[i]
    list_inj3.append(rate)
    
injs = df3['40대'].astype(int)
list_inj4 = []
for i in range(len(injs)-1):
    rate = injs[i+1] / injs[i]
    list_inj4.append(rate)

injs = df3['50대'].astype(int)
list_inj5 = []
for i in range(len(injs)-1):
    rate = injs[i+1] / injs[i]
    list_inj5.append(rate)

injs = df3['60대'].astype(int)
list_inj6 = []
for i in range(len(injs)-1):
    rate = injs[i+1] / injs[i]
    list_inj6.append(rate)
    
injs = df3['65세이상'].astype(int)
list_inj7 = []
for i in range(len(injs)-1):
    rate = injs[i+1] / injs[i]
    list_inj7.append(rate)
    
injs = df3['불명'].astype(int)
list_inj8 = []
for i in range(len(injs)-1):
    rate = injs[i+1] / injs[i]
    list_inj8.append(rate)
    
key = ['10대','20대','30대','40대','50대','60대','65세이상','불명']
list_inj = [list_inj1, list_inj2, list_inj3,list_inj4,list_inj5,list_inj6,list_inj7,list_inj8]
dict_data = dict(zip(key,list_inj))
df_inj = pd.DataFrame(dict_data)
df_inj.index = ['17-18 증가율', '18-19 증가율', '19-20 증가율', '20-21 증가율']
df_inj
# Out:
# C:\Users\taehyun\AppData\Local\Temp\ipykernel_9804\4246731182.py:34: RuntimeWarning: divide by zero encountered in long_scalars
#   rate = injs[i+1] / injs[i]
#                 10대       20대       30대       40대       50대       60대  \
# 17-18 증가율  1.812500  2.468750  1.954545  1.652174  1.428571       inf
# 18-19 증가율  2.379310  2.126582  2.302326  1.421053  2.350000  0.875000
# 19-20 증가율  3.536232  2.011905  1.777778  2.018519  1.255319  2.714286
# 20-21 증가율  2.909836  1.786982  1.357955  1.339450  1.593220  0.842105
#
#               65세이상        불명
# 17-18 증가율  1.333333  0.500000
# 18-19 증가율  1.250000  4.000000
# 19-20 증가율  1.360000  1.500000
# 20-21 증가율  1.941176  4.333333

# %%
# %matplotlib inline
df_acc.plot(y='10대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_acc.plot(y='20대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_acc.plot(y='30대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_acc.plot(y='40대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_acc.plot(y='50대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_acc.plot(y='60대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_acc.plot(y='65세이상',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_acc.plot(y='불명',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
# Out:
# <AxesSubplot:xlabel='기간', ylabel='증가율'>

# %%
# %matplotlib inline
df_inj.plot(y='10대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_inj.plot(y='20대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_inj.plot(y='30대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_inj.plot(y='40대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_inj.plot(y='50대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_inj.plot(y='60대',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_inj.plot(y='65세이상',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
df_inj.plot(y='불명',figsize=(10,6),grid=True,marker='o',xlabel='기간',ylabel='증가율')
# Out:
# <AxesSubplot:xlabel='기간', ylabel='증가율'>
